# %%
import sys
sys.path.insert(0, 'D:/projects/KerasFuzzy/KerasFuzzy/layers')
from fuzzy_layer_2 import FuzzyLayer2
from fuzzy_layer_bell_shaped import FuzzyLayerBell
from fuzzy_layer import FuzzyLayer
from defuzzy_layer_2 import DefuzzyLayer2
from defuzzy_layer import DefuzzyLayer
from logistic_map_layer import LogisticMapLayer

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(2)
random_seed = 2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import backend as K 
import random
from keras.callbacks import EarlyStopping
from keras.callbacks import LearningRateScheduler
import datetime

# %%
train = pd.read_csv("./datasets/train.csv")
test = pd.read_csv("./datasets/test.csv")

Y_train = train["label"]

X_train = train.drop(labels = ["label"], axis = 1) 
del train

# %%
X_train = X_train / 255.0
X_train = X_train.values.reshape(-1,28,28,1)

Y_train = to_categorical(Y_train, num_classes = 10)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.1, random_state=random_seed)

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 3

encoder_inputs = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, 3,
                  padding='same', 
                  activation='relu')(encoder_inputs)
x = layers.Conv2D(64, 3,
                  padding='same', 
                  activation='relu',
                  strides=(2, 2))(x)
x = layers.Conv2D(64, 3,
                  padding='same', 
                  activation='relu')(x)
x = layers.Conv2D(64, 3,
                  padding='same', 
                  activation='relu')(x)

shape_before_flattening = K.int_shape(x)
x = layers.Flatten()(x)
x = layers.UnitNormalization()(x)

#x = layers.Dense(512, activation='sigmoid')(x)
logmap =LogisticMapLayer(5)
x = logmap(x)
z_mean = layers.Dense(latent_dim)(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

fz_c = FuzzyLayer2(10, initial_centers=[
    [ 0.8090169943,  0.5877852524, 0], 
    [ 0.3090169938,  0.9510565165, 0], 
    [-0.3090169938,  0.9510565165, 0], 
    [-0.8090169943,  0.5877852524, 0], 
    [-1.,            0.          , 0], 
    [-0.8090169943, -0.5877852524, 0], 
    [-0.3090169938, -0.9510565165, 0], 
    [ 0.3090169938, -0.9510565165, 0], 
    [ 0.8090169943, -0.5877852524, 0], 
    [ 1.,            0.          , 0]])
fz = fz_c(z_mean)

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z, fz], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 32)   320         ['input_9[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 64)   18496       ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 64)   36928       ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 64)   36928       ['conv2d_18[0][0]']
#
#  flatten_4 (Flatten)            (None, 12544)        0           ['conv2d_19[0][0]']
#
#  unit_normalization_4 (UnitNorm  (None, 12544)       0           ['flatten_4[0][0]']
#  alization)
#
#  logistic_map_layer_4 (Logistic  (None, 12544)       12544       ['unit_normalization_4[0][0]']
#  MapLayer)
#
#  dense_12 (Dense)               (None, 3)            37635       ['logistic_map_layer_4[0][0]']
#
#  z_log_var (Dense)              (None, 3)            37635       ['logistic_map_layer_4[0][0]']
#
#  sampling_4 (Sampling)          (None, 3)            0           ['dense_12[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  fuzzy_layer2_4 (FuzzyLayer2)   (None, 10)           120         ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 180,606
# Trainable params: 180,606
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(latent_dim)(latent_inputs)
x = layers.Dense(np.prod(shape_before_flattening[1:]), activation="relu")(x)
x = layers.Reshape(shape_before_flattening[1:])(x)
x = layers.Conv2DTranspose(64, 3,
                           padding='same', 
                           activation='relu',
                           strides=(2, 2))(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 3)]               0
#
#  dense_13 (Dense)            (None, 3)                 12
#
#  dense_14 (Dense)            (None, 12544)             50176
#
#  reshape_4 (Reshape)         (None, 14, 14, 64)        0
#
#  conv2d_transpose_8 (Conv2DT  (None, 28, 28, 64)       36928
#  ranspose)
#
#  conv2d_transpose_9 (Conv2DT  (None, 28, 28, 1)        577
#  ranspose)
#
# =================================================================
# Total params: 87,693
# Trainable params: 87,693
# Non-trainable params: 0
# _________________________________________________________________

# %%
class FAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(FAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.fz_loss_poisson_tracker = keras.metrics.Mean(name="fz_loss_poisson")
        self.fz_loss_norm_tracker = keras.metrics.Mean(name="fz_loss_norm")
        
    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.fz_loss_poisson_tracker,
            self.fz_loss_norm_tracker
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z, fz = self.encoder(data[0])
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data[0], reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            p = tf.keras.losses.Poisson(reduction=tf.keras.losses.Reduction.SUM)
            fz_loss_norm = tf.reduce_sum(tf.abs(1 - tf.reduce_sum(fz, axis = 1)))
            fz_loss_p = p(data[1], fz) 
            total_loss =  kl_loss  + reconstruction_loss + fz_loss_p + fz_loss_norm

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.fz_loss_poisson_tracker.update_state(fz_loss_p)
        self.kl_loss_tracker.update_state(kl_loss)
        self.fz_loss_norm_tracker.update_state(fz_loss_norm)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "fz_loss_poisson": self.fz_loss_poisson_tracker.result(),
            "fz_loss_norm": self.fz_loss_norm_tracker.result()
        }

fae = FAE(encoder, decoder, name="fae")
    
fae.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3))
log_dir = f"../../logs/fcvae_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

fae.fit(X_train, Y_train,
    epochs=80, 
    batch_size=256, 
    callbacks=[tensorboard_callback])
# Out:
# Epoch 1/80
# 148/148 [==============================] - 12s 63ms/step - loss: 698.4890 - reconstruction_loss: 234.6838 - kl_loss: 8.8237 - fz_loss_poisson: 137.4743 - fz_loss_norm: 69.3539
# Epoch 2/80
# 148/148 [==============================] - 9s 63ms/step - loss: 283.3175 - reconstruction_loss: 182.4973 - kl_loss: 4.8566 - fz_loss_poisson: 75.8964 - fz_loss_norm: 16.1795
# Epoch 3/80
# 148/148 [==============================] - 9s 61ms/step - loss: 278.0930 - reconstruction_loss: 175.3690 - kl_loss: 5.5490 - fz_loss_poisson: 72.7804 - fz_loss_norm: 22.6880
# Epoch 4/80
# 148/148 [==============================] - 9s 62ms/step - loss: 261.8967 - reconstruction_loss: 171.6118 - kl_loss: 5.9563 - fz_loss_poisson: 70.0516 - fz_loss_norm: 18.8310
# Epoch 5/80
# 148/148 [==============================] - 10s 70ms/step - loss: 256.6314 - reconstruction_loss: 168.3232 - kl_loss: 6.2215 - fz_loss_poisson: 67.5592 - fz_loss_norm: 10.1769
# Epoch 6/80
# 148/148 [==============================] - 11s 72ms/step - loss: 254.2667 - reconstruction_loss: 166.7614 - kl_loss: 6.3348 - fz_loss_poisson: 65.5138 - fz_loss_norm: 14.9012
# Epoch 7/80
# 148/148 [==============================] - 10s 66ms/step - loss: 249.4572 - reconstruction_loss: 166.2995 - kl_loss: 6.3416 - fz_loss_poisson: 63.6098 - fz_loss_norm: 14.9570
# Epoch 8/80
# 148/148 [==============================] - 10s 65ms/step - loss: 242.6493 - reconstruction_loss: 165.4359 - kl_loss: 6.4398 - fz_loss_poisson: 61.6426 - fz_loss_norm: 9.8655
# Epoch 9/80
# 148/148 [==============================] - 9s 64ms/step - loss: 243.6078 - reconstruction_loss: 164.5943 - kl_loss: 6.4703 - fz_loss_poisson: 60.0018 - fz_loss_norm: 10.0344
# Epoch 10/80
# 148/148 [==============================] - 9s 63ms/step - loss: 239.0298 - reconstruction_loss: 163.2904 - kl_loss: 6.5982 - fz_loss_poisson: 58.5961 - fz_loss_norm: 8.0403
# Epoch 11/80
# 148/148 [==============================] - 9s 63ms/step - loss: 233.2174 - reconstruction_loss: 161.3552 - kl_loss: 6.7797 - fz_loss_poisson: 57.3246 - fz_loss_norm: 7.0447
# Epoch 12/80
# 148/148 [==============================] - 9s 64ms/step - loss: 229.4560 - reconstruction_loss: 159.7438 - kl_loss: 6.9178 - fz_loss_poisson: 56.0654 - fz_loss_norm: 6.6246
# Epoch 13/80
# 148/148 [==============================] - 9s 64ms/step - loss: 232.7523 - reconstruction_loss: 158.1261 - kl_loss: 7.0053 - fz_loss_poisson: 54.5547 - fz_loss_norm: 11.8400
# Epoch 14/80
# 148/148 [==============================] - 9s 64ms/step - loss: 227.5204 - reconstruction_loss: 156.9673 - kl_loss: 7.1248 - fz_loss_poisson: 53.3039 - fz_loss_norm: 9.2678
# Epoch 15/80
# 148/148 [==============================] - 9s 64ms/step - loss: 222.2308 - reconstruction_loss: 155.5544 - kl_loss: 7.2780 - fz_loss_poisson: 52.4474 - fz_loss_norm: 6.0245
# Epoch 16/80
# 148/148 [==============================] - 10s 64ms/step - loss: 223.0795 - reconstruction_loss: 154.7050 - kl_loss: 7.3512 - fz_loss_poisson: 51.5687 - fz_loss_norm: 7.6919
# Epoch 17/80
# 148/148 [==============================] - 10s 64ms/step - loss: 217.8100 - reconstruction_loss: 153.5933 - kl_loss: 7.4567 - fz_loss_poisson: 50.9054 - fz_loss_norm: 5.6174
# Epoch 18/80
# 148/148 [==============================] - 9s 64ms/step - loss: 217.2086 - reconstruction_loss: 153.2251 - kl_loss: 7.5135 - fz_loss_poisson: 50.2318 - fz_loss_norm: 7.1577
# Epoch 19/80
# 148/148 [==============================] - 10s 65ms/step - loss: 219.8632 - reconstruction_loss: 152.8014 - kl_loss: 7.5326 - fz_loss_poisson: 49.3921 - fz_loss_norm: 8.0442
# Epoch 20/80
# 148/148 [==============================] - 9s 59ms/step - loss: 214.8371 - reconstruction_loss: 152.1516 - kl_loss: 7.6049 - fz_loss_poisson: 48.9893 - fz_loss_norm: 5.6614
# Epoch 21/80
# 148/148 [==============================] - 9s 59ms/step - loss: 214.9824 - reconstruction_loss: 151.6871 - kl_loss: 7.6568 - fz_loss_poisson: 48.4173 - fz_loss_norm: 8.2113
# Epoch 22/80
# 148/148 [==============================] - 9s 59ms/step - loss: 213.1608 - reconstruction_loss: 151.1131 - kl_loss: 7.7093 - fz_loss_poisson: 47.7332 - fz_loss_norm: 7.0742
# Epoch 23/80
# 148/148 [==============================] - 9s 58ms/step - loss: 214.0127 - reconstruction_loss: 150.8997 - kl_loss: 7.7583 - fz_loss_poisson: 47.3496 - fz_loss_norm: 6.8375
# Epoch 24/80
# 148/148 [==============================] - 9s 59ms/step - loss: 209.6547 - reconstruction_loss: 150.3212 - kl_loss: 7.8225 - fz_loss_poisson: 46.9549 - fz_loss_norm: 5.5753
# Epoch 25/80
# 148/148 [==============================] - 9s 59ms/step - loss: 209.9603 - reconstruction_loss: 149.7662 - kl_loss: 7.8989 - fz_loss_poisson: 46.5297 - fz_loss_norm: 6.2615
# Epoch 26/80
# 148/148 [==============================] - 9s 59ms/step - loss: 213.6677 - reconstruction_loss: 149.7959 - kl_loss: 7.8367 - fz_loss_poisson: 46.0723 - fz_loss_norm: 7.4836
# Epoch 27/80
# 148/148 [==============================] - 9s 58ms/step - loss: 207.6431 - reconstruction_loss: 148.8533 - kl_loss: 7.9533 - fz_loss_poisson: 45.7845 - fz_loss_norm: 5.0894
# Epoch 28/80
# 148/148 [==============================] - 9s 58ms/step - loss: 208.7734 - reconstruction_loss: 148.8682 - kl_loss: 8.0202 - fz_loss_poisson: 45.4690 - fz_loss_norm: 5.2946
# Epoch 29/80
# 148/148 [==============================] - 8s 57ms/step - loss: 211.1265 - reconstruction_loss: 149.1151 - kl_loss: 7.9818 - fz_loss_poisson: 44.9342 - fz_loss_norm: 8.3635
# Epoch 30/80
# 148/148 [==============================] - 9s 58ms/step - loss: 207.9576 - reconstruction_loss: 148.1872 - kl_loss: 8.0269 - fz_loss_poisson: 44.5802 - fz_loss_norm: 5.5155
# Epoch 31/80
# 148/148 [==============================] - 9s 59ms/step - loss: 206.0093 - reconstruction_loss: 147.8084 - kl_loss: 8.0916 - fz_loss_poisson: 44.2713 - fz_loss_norm: 5.5280
# Epoch 32/80
# 148/148 [==============================] - 9s 59ms/step - loss: 205.0006 - reconstruction_loss: 147.5694 - kl_loss: 8.1610 - fz_loss_poisson: 44.0116 - fz_loss_norm: 5.2028
# Epoch 33/80
# 148/148 [==============================] - 9s 61ms/step - loss: 205.0679 - reconstruction_loss: 147.3348 - kl_loss: 8.1922 - fz_loss_poisson: 43.7813 - fz_loss_norm: 5.1450
# Epoch 34/80
# 148/148 [==============================] - 9s 60ms/step - loss: 207.9935 - reconstruction_loss: 147.5269 - kl_loss: 8.1619 - fz_loss_poisson: 43.4195 - fz_loss_norm: 6.5499
# Epoch 35/80
# 148/148 [==============================] - 9s 61ms/step - loss: 206.0447 - reconstruction_loss: 146.8769 - kl_loss: 8.2361 - fz_loss_poisson: 43.1090 - fz_loss_norm: 6.2011
# Epoch 36/80
# 148/148 [==============================] - 9s 59ms/step - loss: 203.1422 - reconstruction_loss: 146.5503 - kl_loss: 8.2424 - fz_loss_poisson: 42.8969 - fz_loss_norm: 4.7551
# Epoch 37/80
# 148/148 [==============================] - 9s 57ms/step - loss: 204.1621 - reconstruction_loss: 146.8056 - kl_loss: 8.2818 - fz_loss_poisson: 42.5827 - fz_loss_norm: 7.4026
# Epoch 38/80
# 148/148 [==============================] - 9s 58ms/step - loss: 202.7774 - reconstruction_loss: 146.2553 - kl_loss: 8.2819 - fz_loss_poisson: 42.0961 - fz_loss_norm: 6.5425
# Epoch 39/80
# 148/148 [==============================] - 9s 58ms/step - loss: 202.3410 - reconstruction_loss: 145.8496 - kl_loss: 8.3522 - fz_loss_poisson: 41.7905 - fz_loss_norm: 5.6160
# Epoch 40/80
# 148/148 [==============================] - 8s 57ms/step - loss: 200.7978 - reconstruction_loss: 145.6617 - kl_loss: 8.3381 - fz_loss_poisson: 41.7139 - fz_loss_norm: 5.4837
# Epoch 41/80
# 148/148 [==============================] - 9s 58ms/step - loss: 200.0433 - reconstruction_loss: 145.6675 - kl_loss: 8.3689 - fz_loss_poisson: 41.4969 - fz_loss_norm: 5.6126
# Epoch 42/80
# 148/148 [==============================] - 9s 58ms/step - loss: 201.6280 - reconstruction_loss: 145.3975 - kl_loss: 8.3858 - fz_loss_poisson: 41.1696 - fz_loss_norm: 5.6815
# Epoch 43/80
# 148/148 [==============================] - 9s 58ms/step - loss: 200.1982 - reconstruction_loss: 145.1212 - kl_loss: 8.3784 - fz_loss_poisson: 41.0873 - fz_loss_norm: 5.0999
# Epoch 44/80
# 148/148 [==============================] - 9s 58ms/step - loss: 199.4635 - reconstruction_loss: 144.7944 - kl_loss: 8.4452 - fz_loss_poisson: 40.8617 - fz_loss_norm: 4.8733
# Epoch 45/80
# 148/148 [==============================] - 9s 58ms/step - loss: 198.9993 - reconstruction_loss: 144.4882 - kl_loss: 8.4449 - fz_loss_poisson: 40.6933 - fz_loss_norm: 5.0886
# Epoch 46/80
# 148/148 [==============================] - 9s 58ms/step - loss: 198.2275 - reconstruction_loss: 144.2839 - kl_loss: 8.4627 - fz_loss_poisson: 40.4914 - fz_loss_norm: 4.8134
# Epoch 47/80
# 148/148 [==============================] - 9s 58ms/step - loss: 198.6362 - reconstruction_loss: 144.3631 - kl_loss: 8.4802 - fz_loss_poisson: 40.4328 - fz_loss_norm: 4.6003
# Epoch 48/80
# 148/148 [==============================] - 9s 58ms/step - loss: 197.9405 - reconstruction_loss: 144.1808 - kl_loss: 8.5045 - fz_loss_poisson: 40.2286 - fz_loss_norm: 4.7324
# Epoch 49/80
# 148/148 [==============================] - 9s 59ms/step - loss: 199.6935 - reconstruction_loss: 144.4310 - kl_loss: 8.4792 - fz_loss_poisson: 39.8860 - fz_loss_norm: 7.1652
# Epoch 50/80
# 148/148 [==============================] - 9s 58ms/step - loss: 196.9891 - reconstruction_loss: 143.8272 - kl_loss: 8.5417 - fz_loss_poisson: 39.6301 - fz_loss_norm: 4.6693
# Epoch 51/80
# 148/148 [==============================] - 9s 57ms/step - loss: 196.5763 - reconstruction_loss: 143.7868 - kl_loss: 8.5802 - fz_loss_poisson: 39.5979 - fz_loss_norm: 5.0053
# Epoch 52/80
# 148/148 [==============================] - 8s 57ms/step - loss: 196.7187 - reconstruction_loss: 143.4223 - kl_loss: 8.5710 - fz_loss_poisson: 39.4190 - fz_loss_norm: 5.0827
# Epoch 53/80
# 148/148 [==============================] - 8s 57ms/step - loss: 196.3908 - reconstruction_loss: 143.4212 - kl_loss: 8.6168 - fz_loss_poisson: 39.2969 - fz_loss_norm: 4.6401
# Epoch 54/80
# 148/148 [==============================] - 8s 57ms/step - loss: 195.9770 - reconstruction_loss: 143.2476 - kl_loss: 8.6115 - fz_loss_poisson: 39.1897 - fz_loss_norm: 4.8692
# Epoch 55/80
# 148/148 [==============================] - 8s 57ms/step - loss: 196.9940 - reconstruction_loss: 143.0970 - kl_loss: 8.6491 - fz_loss_poisson: 38.9324 - fz_loss_norm: 5.3859
# Epoch 56/80
# 148/148 [==============================] - 8s 57ms/step - loss: 194.8752 - reconstruction_loss: 142.7726 - kl_loss: 8.6569 - fz_loss_poisson: 38.8356 - fz_loss_norm: 5.1881
# Epoch 57/80
# 148/148 [==============================] - 8s 57ms/step - loss: 196.4854 - reconstruction_loss: 142.8492 - kl_loss: 8.6827 - fz_loss_poisson: 38.6184 - fz_loss_norm: 5.1292
# Epoch 58/80
# 148/148 [==============================] - 9s 58ms/step - loss: 194.4980 - reconstruction_loss: 142.5729 - kl_loss: 8.6748 - fz_loss_poisson: 38.5483 - fz_loss_norm: 4.9667
# Epoch 59/80
# 148/148 [==============================] - 9s 58ms/step - loss: 194.7752 - reconstruction_loss: 142.4399 - kl_loss: 8.7047 - fz_loss_poisson: 38.5048 - fz_loss_norm: 4.5376
# Epoch 60/80
# 148/148 [==============================] - 8s 57ms/step - loss: 193.4941 - reconstruction_loss: 142.1242 - kl_loss: 8.7274 - fz_loss_poisson: 38.3584 - fz_loss_norm: 4.6212
# Epoch 61/80
# 148/148 [==============================] - 9s 58ms/step - loss: 193.8400 - reconstruction_loss: 142.0497 - kl_loss: 8.7286 - fz_loss_poisson: 38.2618 - fz_loss_norm: 4.8329
# Epoch 62/80
# 148/148 [==============================] - 9s 58ms/step - loss: 193.0476 - reconstruction_loss: 142.0081 - kl_loss: 8.7258 - fz_loss_poisson: 38.1211 - fz_loss_norm: 5.0386
# Epoch 63/80
# 148/148 [==============================] - 9s 58ms/step - loss: 192.9678 - reconstruction_loss: 141.7725 - kl_loss: 8.7336 - fz_loss_poisson: 37.9760 - fz_loss_norm: 4.6631
# Epoch 64/80
# 148/148 [==============================] - 9s 58ms/step - loss: 195.1601 - reconstruction_loss: 141.9386 - kl_loss: 8.7341 - fz_loss_poisson: 37.8235 - fz_loss_norm: 5.3002
# Epoch 65/80
# 148/148 [==============================] - 9s 58ms/step - loss: 193.1019 - reconstruction_loss: 141.7741 - kl_loss: 8.7721 - fz_loss_poisson: 37.7890 - fz_loss_norm: 4.6520
# Epoch 66/80
# 148/148 [==============================] - 8s 57ms/step - loss: 192.6910 - reconstruction_loss: 141.8377 - kl_loss: 8.7655 - fz_loss_poisson: 37.6961 - fz_loss_norm: 5.2431
# Epoch 67/80
# 148/148 [==============================] - 9s 58ms/step - loss: 193.1518 - reconstruction_loss: 141.3849 - kl_loss: 8.7756 - fz_loss_poisson: 37.5119 - fz_loss_norm: 5.1005
# Epoch 68/80
# 148/148 [==============================] - 8s 57ms/step - loss: 193.8849 - reconstruction_loss: 141.7587 - kl_loss: 8.7417 - fz_loss_poisson: 37.4632 - fz_loss_norm: 5.7440
# Epoch 69/80
# 148/148 [==============================] - 9s 57ms/step - loss: 191.5983 - reconstruction_loss: 141.0879 - kl_loss: 8.7993 - fz_loss_poisson: 37.3394 - fz_loss_norm: 4.3884
# Epoch 70/80
# 148/148 [==============================] - 9s 58ms/step - loss: 192.2043 - reconstruction_loss: 141.3173 - kl_loss: 8.7507 - fz_loss_poisson: 37.2837 - fz_loss_norm: 5.1563
# Epoch 71/80
# 148/148 [==============================] - 9s 59ms/step - loss: 191.9683 - reconstruction_loss: 141.2391 - kl_loss: 8.7981 - fz_loss_poisson: 37.2902 - fz_loss_norm: 4.7045
# Epoch 72/80
# 148/148 [==============================] - 9s 58ms/step - loss: 191.4719 - reconstruction_loss: 140.9031 - kl_loss: 8.7789 - fz_loss_poisson: 37.1878 - fz_loss_norm: 4.2144
# Epoch 73/80
# 148/148 [==============================] - 9s 58ms/step - loss: 192.2641 - reconstruction_loss: 140.6994 - kl_loss: 8.8033 - fz_loss_poisson: 37.1221 - fz_loss_norm: 4.9435
# Epoch 74/80
# 148/148 [==============================] - 9s 58ms/step - loss: 191.0755 - reconstruction_loss: 140.7871 - kl_loss: 8.7719 - fz_loss_poisson: 37.0642 - fz_loss_norm: 4.5094
# Epoch 75/80
# 148/148 [==============================] - 9s 59ms/step - loss: 192.0987 - reconstruction_loss: 140.8791 - kl_loss: 8.7365 - fz_loss_poisson: 37.0672 - fz_loss_norm: 4.5012
# Epoch 76/80
# 148/148 [==============================] - 9s 59ms/step - loss: 190.1322 - reconstruction_loss: 140.4099 - kl_loss: 8.7859 - fz_loss_poisson: 36.9657 - fz_loss_norm: 3.8175
# Epoch 77/80
# 148/148 [==============================] - 9s 58ms/step - loss: 189.4462 - reconstruction_loss: 140.3404 - kl_loss: 8.7679 - fz_loss_poisson: 36.9781 - fz_loss_norm: 3.8992
# Epoch 78/80
# 148/148 [==============================] - 9s 58ms/step - loss: 190.3849 - reconstruction_loss: 140.4643 - kl_loss: 8.7731 - fz_loss_poisson: 36.9500 - fz_loss_norm: 3.8974
# Epoch 79/80
# 148/148 [==============================] - 8s 57ms/step - loss: 190.4098 - reconstruction_loss: 140.5440 - kl_loss: 8.7545 - fz_loss_poisson: 36.8593 - fz_loss_norm: 4.6128
# Epoch 80/80
# 148/148 [==============================] - 9s 57ms/step - loss: 189.9014 - reconstruction_loss: 140.2397 - kl_loss: 8.7643 - fz_loss_poisson: 36.8754 - fz_loss_norm: 3.9213

# %%
fae_class = keras.Model(encoder_inputs, fz)
fae_class.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
fae_class.evaluate(X_val, Y_val)
# Out:
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.8895
# [0.0, 0.8895238041877747]

# %%
logmap.r_values
# Out:
# <tf.Variable 'logistic_map_layer_4/Variable:0' shape=(12544,) dtype=float32, numpy=
# array([3.5418854, 3.563951 , 3.57327  , ..., 3.5756931, 3.56995  ,
#        3.5641072], dtype=float32)>

# %% [markdown]
# ## 3. Visualization <a class="anchor" id="viz"></a>
# [Back to Table of Contents](#bcImp)

# %%
fuzzy_cvae = keras.Model(encoder_inputs, z_mean)
fae_class = keras.Model(encoder_inputs, fz)

def plot_label_clusters(fae, data, labels):
    z_means = fae.predict(data)
    fig, ax = plt.subplots(ncols=latent_dim, nrows=latent_dim, figsize=(15, 15), squeeze=False)
    for bdim in range(latent_dim):
        for odim in range(latent_dim):
            ax[bdim, odim].scatter(z_means[:, bdim], z_means[:, odim], c=labels)
            ax[bdim, odim].set_xlabel(f"z[{bdim}]")
            ax[bdim, odim].set_ylabel(f"z[{odim}]")
    
    plt.show()

labels = [np.argmax(a) for a in Y_val]
plot_label_clusters(fuzzy_cvae, X_val, labels)
# Out:
# 132/132 [==============================] - 0s 2ms/step

# %%
random_images = np.random.rand(3000, 28, 28, 1)

#plt.imshow(random_images[0][:,:,0])

x_val_and_anom = np.concatenate([X_val, random_images], axis=0)
labels =np.concatenate( [[0 for a in Y_val], [1 for a in random_images]], axis=0)

plot_label_clusters(fuzzy_cvae, x_val_and_anom, labels)
# Out:
# 225/225 [==============================] - 0s 2ms/step

# %%
from sklearn.neighbors import LocalOutlierFactor

mnist_train_pred = fae_class.predict(X_train)
mnist_val_pred = fae_class.predict(X_val)
random_images_pred = fae_class.predict(random_images)

def convert_to_descriptive_stats_vector(arr):
    retval = []
    for a in arr:
        retval.append([np.max(a), np.min(a), np.mean(a), np.sum(a)])
    return retval

converted_mnist_train = convert_to_descriptive_stats_vector(mnist_train_pred)
converted_mnist_val = convert_to_descriptive_stats_vector(mnist_val_pred)
converted_random = convert_to_descriptive_stats_vector(random_images_pred)
# Out:
# 1182/1182 [==============================] - 3s 3ms/step
# 132/132 [==============================] - 0s 3ms/step
# 94/94 [==============================] - 0s 3ms/step

# %%
clf = LocalOutlierFactor(n_neighbors=1000, novelty=True)
clf.fit(converted_mnist_train)

print(f"MNIST train inliers rate:{np.mean([0 if a<0 else 1 for a in clf.predict(converted_mnist_train)])}")
print(f"MNIST val inliers rate:{np.mean([0 if a<0 else 1 for a in clf.predict(converted_mnist_val)])}")
print(f"Random inliers rate:{np.mean([0 if a<0 else 1 for a in clf.predict(converted_random)])}")
# Out:
# MNIST train inliers rate:0.9374603174603174
# MNIST val inliers rate:0.8911904761904762
# Random inliers rate:0.8213333333333334
